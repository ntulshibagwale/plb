# %% [markdown]
# # Connect to Weights and Biases Servers

# %%
# !pip install wandb -qqq
import wandb
wandb.login() # Log in to your W&B account
# Out:
# wandb: Currently logged in as: ntulshibagwale (ae-ml_ucsb). Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Import Modules, Set Random Seeds, and Access the Power of Google Colab

# %%
import os
import random
import numpy as np
import torch
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report
from torch.utils.data import Dataset
from torch import tensor
import torch.nn as nn
from tqdm.notebook import tqdm
import re, json, requests

# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
random.seed(hash("setting random seeds") % 2**32 - 1)
np.random.seed(hash("improves reproducibility") % 2**32 - 1)
torch.manual_seed(hash("by removing stochasticity") % 2**32 - 1)
torch.cuda.manual_seed_all(hash("so runs are repeatable") % 2**32 - 1)

# Device configuration
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Define Machine Learning Pipeline and Utility Functions

# %%
def model_pipeline(config=None): 

    # tell wandb to get started
    with wandb.init(project=None, config=None):
      # access all HPs through wandb.config, so logging matches execution!
      config = wandb.config

      print("HYPER-Parameters:")
      for key,value in config.items():
        print(key, ':', value)
      print("")

      # make the model, data, and optimization problem
      model, train_loader, test_loader, criterion, optimizer = make(config)
      print(model)
      
      print('-----------------------------------------------------------------')
      print("Begin model training...\n")
      # and use them to train the model
      train(model, train_loader, criterion, optimizer, config)
      print("Training completed.\n")
      print('-----------------------------------------------------------------')
      
      print("Begin model evaluation...\n")
      print("\nEvaluate results on test data...\n")
      # and test its final performance
      test(model, test_loader, config)


    return model

def make(config):
    # Make the data
    train, test = get_data(config) 
    y_test = torch.argmax(test[:][1], dim=1)
    y_train = torch.argmax(train[:][1], dim=1)
    wandb.sklearn.plot_class_proportions(y_train,y_test, config.angles)
  
    train_loader = make_loader(train, batch_size=config.batch_size)
    test_loader = make_loader(test, batch_size=config.batch_size)
  
    # Make the model
    model = NeuralNetwork_01(config.feature_dim, config.classes).to(device)

    # Make the loss and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(
        model.parameters(), lr=config.learning_rate)
    
    # Look at shapes of batches
    for ex_idx, (batch_x,batch_y) in enumerate(train_loader):
        print(f"Shape of x batch is: {batch_x.shape}")
        print(f"Datatype of x batch is: {batch_x.dtype}\n")
        print(f"Shape of y batch is: {batch_y.shape}")
        print(f"Datatype of y batch is: {batch_y.dtype}\n")
        break

    return model, train_loader, test_loader, criterion, optimizer

def get_data(config):

    ae_dataset = AcousticEmissionDataset(config.url,
                                         config.sig_len,
                                         config.dt,
                                         config.low_pass,
                                         config.high_pass,
                                         config.fft_units,
                                         config.num_bins)
    
    total_count = len(ae_dataset)
    test_percent = 1 - config.train_percent
    train_count = int(config.train_percent * total_count)
    test_count = total_count - train_count
    torch.manual_seed(config.train_seed) 
    train, test = torch.utils.data.random_split(ae_dataset,
                                                      (train_count,
                                                        test_count))

    return train, test

def make_loader(dataset, batch_size):
    loader = torch.utils.data.DataLoader(dataset=dataset,
                                         batch_size=batch_size, 
                                         shuffle=True,
                                         pin_memory=True, num_workers=2)
    return loader

def train(model, loader, criterion, optimizer, config):
    # Tell wandb to watch what the model gets up to: gradients, weights, etc
    wandb.watch(model, criterion, log="all", log_freq=10)

    # Run training and track with wandb
    total_batches = len(loader) * config.epochs
    example_ct = 0  # number of examples seen
    batch_ct = 0
    for epoch in tqdm(range(config.epochs)):
        for _, (waves, targets) in enumerate(loader):

            loss = train_batch(waves, targets, model, optimizer, criterion)
            example_ct +=  len(waves)
            batch_ct += 1

            # Report metrics every 25th batch
            if ((batch_ct + 1) % 25) == 0:
                train_log(loss, example_ct, epoch)

def train_batch(waves, targets, model, optimizer, criterion):
    waves, targets = waves.to(device), targets.to(device)

    # Forward pass ➡
    outputs = model(waves)
    loss = criterion(outputs, targets)
    
    # Backward pass ⬅
    optimizer.zero_grad()
    loss.backward()

    # Step with optimizer
    optimizer.step()

    return loss

def train_log(loss, example_ct, epoch):
    # Where the magic happens
    wandb.log({"epoch": epoch, "loss": loss}, step=example_ct)
    print(f"Loss after " + str(example_ct).zfill(5) + f" examples: {loss:.3f}")

def flatten(t):
    return [item for sublist in t for item in sublist]

def test(model, test_loader, config):
    model.eval()

    # Run the model on some test examples
    with torch.no_grad():
      test_predicted = []
      test_targets = []
      correct, total = 0, 0
      i = 0
      for waves, targets in test_loader:
        waves, targets = waves.to(device), targets.to(device)
        outputs = model(waves)
        _, predicted = torch.max(outputs, 1)
        _, targets = torch.max(targets, 1)
        total += targets.size(0)
        correct += (predicted == targets).sum().item()
        test_predicted.append(predicted) # ex. [0,0,1]
        test_targets.append(targets)

        print(f"Accuracy of the model on the {total} " +
              f"test waves: {100 * correct / total}%")
        
    print("")
    print("Test Set Metrics:")
    # Obnoxious coding to get into some correct format
    test_predicted = [t.numpy() for t in test_predicted]
    test_targets = [t.numpy() for t in test_targets]
    #test_predicted = np.array(test_predicted).flatten()
    test_targets = flatten(test_targets)
    test_predicted = flatten(test_predicted)
    print(classification_report(test_predicted,test_targets,
                                target_names=config.angles))
    
    metrics = classification_report(test_predicted,test_targets,
                                target_names=config.angles,output_dict=True)
    wandb.log(metrics)  
    wandb.log({"test_accuracy": correct / total})
    
    torch.save(model.state_dict(), 'model.pth')
    wandb.save("model.pth")

def load_PLB(url):

    url = 'https://raw.githubusercontent.com/ntulshibagwale/plb_dataset_supervised_learning/main/Data/220426_PLB_data.json'
    resp = requests.get(url)
    PLB = json.loads(resp.text)
    for key in PLB.keys():
        PLB[key]  = np.array(PLB[key])
    return PLB

# %% [markdown]
# # Define AE Pencil Lead Break Dataset

# %%
class AcousticEmissionDataset(Dataset):
    
    # Constructor
    def __init__(self,url,sig_len,dt,low_pass,high_pass,fft_units,
                 num_bins):
      
        self.url = url
        self.sig_len = sig_len
        self.dt = dt
        self.low_pass = low_pass
        self.high_pass = high_pass
        self.fft_units = fft_units
        self.num_bins = num_bins
        
        # Load in AE Data
        data = load_PLB(url)
        
        # Separate dict into arrays
        waves = data['data']           # List of raw waveforms
        targets = data['target']       # waveform labels
        self.angles = data['target_angle']  # angle, one hot encoded
        self.targets = tensor(targets,dtype=torch.int64,requires_grad=False)
      
        # One hot encode
        targets_one_hot = tensor(targets,dtype=torch.int64,requires_grad=False)
        targets_one_hot = torch.nn.functional.one_hot(targets_one_hot.long()) 
        self.targets_one_hot = targets_one_hot.float()
        print("targets_one_hot is the one hot encoding for angle. ex: [1 0 1]")

        self.n_samples = self.targets.shape[0]    # Number of samples/labels
        self.waves = tensor(waves,dtype=torch.float32,requires_grad=False)                          
                   
        print("")
        print(f"Shape of waves is: {self.waves.shape}")
        print(f"Datatype of waves is: {self.waves.dtype}")
        print("waves requires grad:", self.waves.requires_grad)
        print(f"Shape of targets is: {self.targets.shape}")
        print(f"Datatype of targets is: {self.targets.dtype}")
        print("targets requires grad:", self.targets.requires_grad)
        print(f"Ex: {targets[0]}")
        print(f"Shape of targets_one_hot is: {self.targets_one_hot.shape}")
        print(f"Datatype of targets_one_hot is: {self.targets_one_hot.dtype}")
        print("targets_one_hot requires grad:", \
              self.targets_one_hot.requires_grad)
        print(f"Ex: {targets_one_hot[0]}")
        print("")
        
        print("AcousticEmissionDataset loaded in!\n")
        
    def __getitem__(self,index):
        """
        
        Function called when object is indexed. The transformation of data 
        occurs in this getter function. In other words, the constructor reads
        in the raw data filtered by hand, and this function contains the 
        sequence of remaining processing on the data to extract features used
        in ML models.
        
        index (int): the index of the sample and label
        
        return:
        (x,y): feature vector and label corresponding to single event
        
        """
        x = self.waves[index]      
        y = self.targets_one_hot[index] 
              
        return x, y # input example, label
    
    def __len__(self): # number of samples
        return self.n_samples
  
    def _get_angle_subset(self, specific_angles):
        """
        
        Get subset of AE data based on angle.

        Parameters
        ----------
        specific_angles : array-like
            List of angles that a sub-dataset will be composed of.

        Returns
        -------
        subset : Pytorch Dataset Object
            Object for training / testing, containing specified angles.

        """
        targets = self.targets # use int label for which angle it is
        indices = []
        for idx, target in enumerate(targets): # loop through all data
            if self.angles[target] in specific_angles:
                indices.append(idx) # if angle is a match remember index
        
        subset = torch.utils.data.Subset(self,indices) # get subset
        
        return subset

# %% [markdown]
# # Define Network Architecture

# %%
class NeuralNetwork_01(nn.Module): 
    # classification
    def __init__(self, feature_dim, classes):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(feature_dim, 20),
            nn.ReLU(),
            nn.Linear(20,classes)
        )

    def forward(self, x):
        z = self.layers(x)
        return z # predictions

# %% [markdown]
# ## Enter Hyperparameters and Train Model

# %%
sweep_config = {
  "name" : "sweep2",
  "method" : "bayes",
  "metric" : {
    'goal': 'maximize',
    'name': 'accuracy'
  },
  "parameters" : {
    "epochs" : {
      "min": 1000,
      "max": 2000
    },
    "learning_rate" :{
      "min": 0.0001,
      "max": 0.01
    },
    "classes" : {
        'value' : 6
    },
    "batch_size" : {
        "values" : [10,50,128]
    },
    "train_percent" : {
        "value" : 0.8
    },
    "url" : {
        "value" : 'https://raw.githubusercontent.com/ntulshibagwale/plb_dataset_supervised_learning/main/Data/220426_PLB_data.json'
    },
    'architecture' : {
        "value" : 1
    },
    "feature_dim" : {
        "value" : 1024
    },
    "sig_len" : {
        "value" : 1024
    },
    "dt" : {
        "value" : 10**-7
    },
    "low_pass" : {
        "value" : 0
    },
    "high_pass" : {
        "value" : 100*10**4
    },
    "fft_units" : {
        "value" : 1000
    },
    "num_bins" : {
        "value" : 26
    },
    "train_seed" : {
        "value" : 41
    },
    "angles" : {
        "value" : ['20deg', '22deg', '26deg', '30deg', '36deg', '40deg']
    }
  }
}

sweep_id = wandb.sweep(sweep_config,project="plb-dataset")
wandb.agent(sweep_id, function=model_pipeline, count=10)
# Out:
# Create sweep with ID: gjo2tho0
# Sweep URL: https://wandb.ai/ae-ml_ucsb/plb-dataset/sweeps/gjo2tho0
# wandb: Agent Starting Run: y2tk2nzq with config:
# wandb: 	angles: ['20deg', '22deg', '26deg', '30deg', '36deg', '40deg']
# wandb: 	architecture: 1
# wandb: 	batch_size: 128
# wandb: 	classes: 6
# wandb: 	dt: 1e-07
# wandb: 	epochs: 1097
# wandb: 	feature_dim: 1024
# wandb: 	fft_units: 1000
# wandb: 	high_pass: 1000000
# wandb: 	learning_rate: 0.00874416963166661
# wandb: 	low_pass: 0
# wandb: 	num_bins: 26
# wandb: 	sig_len: 1024
# wandb: 	train_percent: 0.8
# wandb: 	train_seed: 41
# wandb: 	url: https://raw.githubusercontent.com/ntulshibagwale/plb_dataset_supervised_learning/main/Data/220426_PLB_data.json
# wandb: Currently logged in as: ntulshibagwale (ae-ml_ucsb). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220527_121722-y2tk2nzq</code>
# Syncing run <strong><a href="https://wandb.ai/ae-ml_ucsb/plb-dataset/runs/y2tk2nzq" target="_blank">amber-sweep-1</a></strong> to <a href="https://wandb.ai/ae-ml_ucsb/plb-dataset" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ae-ml_ucsb/plb-dataset/sweeps/gjo2tho0" target="_blank">https://wandb.ai/ae-ml_ucsb/plb-dataset/sweeps/gjo2tho0</a>
# HYPER-Parameters:
# angles : ['20deg', '22deg', '26deg', '30deg', '36deg', '40deg']
# architecture : 1
# batch_size : 128
# classes : 6
# dt : 1e-07
# epochs : 1097
# feature_dim : 1024
# fft_units : 1000
# high_pass : 1000000
# learning_rate : 0.00874416963166661
# low_pass : 0
# num_bins : 26
# sig_len : 1024
# train_percent : 0.8
# train_seed : 41
# url : https://raw.githubusercontent.com/ntulshibagwale/plb_dataset_supervised_learning/main/Data/220426_PLB_data.json
#
# targets_one_hot is the one hot encoding for angle. ex: [1 0 1]
#
# Shape of waves is: torch.Size([514, 1024])
# Datatype of waves is: torch.float32
# waves requires grad: False
# Shape of targets is: torch.Size([514])
# Datatype of targets is: torch.int64
# targets requires grad: False
# Ex: 0
# Shape of targets_one_hot is: torch.Size([514, 6])
# Datatype of targets_one_hot is: torch.float32
# targets_one_hot requires grad: False
# Ex: tensor([1, 0, 0, 0, 0, 0])
#
# AcousticEmissionDataset loaded in!
#
# Shape of x batch is: torch.Size([128, 1024])
# Datatype of x batch is: torch.float32
#
# Shape of y batch is: torch.Size([128, 6])
# Datatype of y batch is: torch.float32
#
# NeuralNetwork_01(
#   (layers): Sequential(
#     (0): Linear(in_features=1024, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features
# Loss after 241385 examples: 0.017
# Loss after 243979 examples: 0.012
# Loss after 246573 examples: 0.013
# Loss after 249066 examples: 0.020
# Loss after 251660 examples: 0.013
# Loss after 254254 examples: 0.012
# Loss after 256848 examples: 0.013
# Loss after 259341 examples: 0.009
# Loss after 261935 examples: 0.011
# Loss after 264529 examples: 0.014
# Loss after 267123 examples: 0.015
# Loss after 269616 examples: 0.015
# Loss after 272210 examples: 0.014
# Loss after 274804 examples: 0.012
# Loss after 277398 examples: 0.013
# Loss after 279891 examples: 0.016
# Loss after 282485 examples: 0.011
# Loss after 285079 examples: 0.011
# Loss after 287673 examples: 0.025
# Loss after 290166 examples: 0.020
# Loss after 292760 examples: 0.011
# Loss after 295354 examples: 0.015
# Loss after 297948 examples: 0.014
# Loss after 300441 examples: 0.017
# Loss after 303035 examples: 0.013
# Loss after 305629 examples: 0.009
# Loss after 308223 examples: 0.013
# Loss after 310716 examples: 0.020
# Loss after 313310 examples: 0.012
# Loss after 315904 examples: 0.009
# Loss after 318498 examples: 0.011
# Loss after 320991 examples: 0.007
# Loss after 323585 examples: 0.015
# Loss after 326179 examples: 0.014
# Loss after 328773 examples: 0.011
# Loss after 331266 examples: 0.013
# Loss after 333860 examples: 0.013
# Loss after 336454 examples: 0.013
# Loss after 339048 examples: 0.012
# Loss after 341541 examples: 0.010
# Loss after 344135 examples: 0.014
# Loss after 346729 examples: 0.012
# Loss after 349323 examples: 0.011
# Loss after 351816 examples: 0.012
# Loss after 354410 examples: 0.011
# Loss after 357004 examples: 0.014
# Loss after 359598 examples: 0.012
# Loss after 362091 examples: 0.016
# Loss after 364685 examples: 0.012
# Loss after 367279 examples: 0.012
# Loss after 369873 examples: 0.016
# Loss after 372366 examples: 0.009
# Loss after 374960 examples: 0.016
# Loss after 377554 examples: 0.012
# Loss after 380148 examples: 0.015
# Loss after 382641 examples: 0.014
# Loss after 385235 examples: 0.017
# Loss after 387829 examples: 0.011
# Loss after 390423 examples: 0.009
# Loss after 392916 examples: 0.016
# Loss after 395510 examples: 0.012
# Loss after 398104 examples: 0.012
# Loss after 400698 examples: 0.010
# Loss after 403191 examples: 0.016
# Loss after 405785 examples: 0.009
# Loss after 408379 examples: 0.012
# Loss after 410973 examples: 0.008
# Loss after 413466 examples: 0.010
# Loss after 416060 examples: 0.009
# Loss after 418654 examples: 0.012
# Loss after 421248 examples: 0.010
# Loss after 423741 examples: 0.007
# Loss after 426335 examples: 0.010
# Loss after 428929 examples: 0.011
# Loss after 431523 examples: 0.008
# Loss after 434016 examples: 0.008
# Loss after 436610 examples: 0.015
# Loss after 439204 examples: 0.009
# Loss after 441798 examples: 0.010
# Loss after 444291 examples: 0.011
# Loss after 446885 examples: 0.012
# Loss after 449479 examples: 0.010
# Training completed.
#
# -----------------------------------------------------------------
# Begin model evaluation...
#
#
# Evaluate results on test data...
#
# Accuracy of the model on the 103 test waves: 96.11650485436893%
#
# Test Set Metrics:
#               precision    recall  f1-score   support
#
#        20deg       1.00      1.00      1.00        20
#        22deg       1.00      1.00      1.00        15
#        26deg       1.00      0.95      0.97        20
#        30deg       0.88      0.88      0.88        17
#        36deg       0.93      0.93      0.93        15
#        40deg       0.94      1.00      0.97        16
#
#     accuracy                           0.96       103
#    macro avg       0.96      0.96      0.96       103
# weighted avg       0.96      0.96      0.96       103
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.082 MB of 0.082 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▇▅▄▄▃▄▂▂▂▂▂▂▂▂▂▂▂▁▄▂▂▁▁▁▂▂▁▁▁▂▁▁▂▂▁▁▁▁▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96117</td></tr><tr><td>epoch</td><td>1093</td></tr><tr><td>loss</td><td>0.01016</td></tr><tr><td>test_accuracy</td><td>0.96117</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">amber-sweep-1</strong>: <a href="https://wandb.ai/ae-ml_ucsb/plb-dataset/runs/y2tk2nzq" target="_blank">https://wandb.ai/ae-ml_ucsb/plb-dataset/runs/y2tk2nzq</a><br/>Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220527_121722-y2tk2nzq/logs</code>
# wandb: Agent Starting Run: 6j9we3jw with config:
# wandb: 	angles: ['20deg', '22deg', '26deg', '30deg', '36deg', '40deg']
# wandb: 	architecture: 1
# wandb: 	batch_size: 50
# wandb: 	classes: 6
# wandb: 	dt: 1e-07
# wandb: 	epochs: 1344
# wandb: 	feature_dim: 1024
# wandb: 	fft_units: 1000
# wandb: 	high_pass: 1000000
# wandb: 	learning_rate: 0.00015545780336759517
# wandb: 	low_pass: 0
# wandb: 	num_bins: 26
# wandb: 	sig_len: 1024
# wandb: 	train_percent: 0.8
# wandb: 	train_seed: 41
# wandb: 	url: https://raw.githubusercontent.com/ntulshibagwale/plb_dataset_supervised_learning/main/Data/220426_PLB_data.json
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220527_121958-6j9we3jw</code>
# Syncing run <strong><a href="https://wandb.ai/ae-ml_ucsb/plb-dataset/runs/6j9we3jw" target="_blank">usual-sweep-2</a></strong> to <a href="https://wandb.ai/ae-ml_ucsb/plb-dataset" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ae-ml_ucsb/plb-dataset/sweeps/gjo2tho0" target="_blank">https://wandb.ai/ae-ml_ucsb/plb-dataset/sweeps/gjo2tho0</a>
# HYPER-Parameters:
# angles : ['20deg', '22deg', '26deg', '30deg', '36deg', '40deg']
# architecture : 1
# batch_size : 50
# classes : 6
# dt : 1e-07
# epochs : 1344
# feature_dim : 1024
# fft_units : 1000
# high_pass : 1000000
# learning_rate : 0.00015545780336759517
# low_pass : 0
# num_bins : 26
# sig_len : 1024
# train_percent : 0.8
# train_seed : 41
# url : https://raw.githubusercontent.com/ntulshibagwale/plb_dataset_supervised_learning/main/Data/220426_PLB_data.json
#
# targets_one_hot is the one hot encoding for angle. ex: [1 0 1]
#
# Shape of waves is: torch.Size([514, 1024])
# Datatype of waves is: torch.float32
# waves requires grad: False
# Shape of targets is: torch.Size([514])
# Datatype of targets is: torch.int64
# targets requires grad: False
# Ex: 0
# Shape of targets_one_hot is: torch.Size([514, 6])
# Datatype of targets_one_hot is: torch.float32
# targets_one_hot requires grad: False
# Ex: tensor([1, 0, 0, 0, 0, 0])
#
# AcousticEmissionDataset loaded in!
#
# Shape of x batch is: torch.Size([50, 1024])
# Datatype of x batch is: torch.float32
#
# Shape of y batch is: torch.Size([50, 6])
# Datatype of y batch is: torch.float32
#
# NeuralNetwork_01(
#   (layers): Sequential(
#     (0): Linear(in_features=1024, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=6, bias=True)
#   )
# )
# -----------------------------------------------------------------
# Begin model training...
#   0%|          | 0/1344 [00:00<?, ?it/s]
# Loss after 01122 examples: 0.146
# Loss after 02255 examples: 0.138
# Loss after 03388 examples: 0.137
# Loss after 04521 examples: 0.137
# Loss after 05693 examples: 0.125
# Loss after 06826 examples: 0.111
# Loss after 07959 examples: 0.116
# Loss after 09092 examples: 0.105
# Loss after 10264 examples: 0.103
# Loss after 11397 examples: 0.106
# Loss after 12530 examples: 0.108
# Loss after 13663 examples: 0.107
# Loss after 14796 examples: 0.113
# Loss after 15968 examples: 0.097
# Loss after 17101 examples: 0.098
# Loss after 18234 examples: 0.104
# Loss after 19367 examples: 0.095
# Loss after 20539 examples: 0.092
# Loss after 21672 examples: 0.091
# Loss after 22805 examples: 0.098
# Loss after 23938 examples: 0.081
# Loss after 25071 examples: 0.093
# Loss after 26243 examples: 0.087
# Loss after 27376 examples: 0.092
# Loss after 28509 examples: 0.085
# Loss after 29642 examples: 0.089
# Loss after 30814 examples: 0.089
# Loss after 31947 examples: 0.088
# Loss after 33080 examples: 0.089
# Loss after 34213 examples: 0.084
# Loss after 35346 examples: 0.088
# Loss after 36518 examples: 0.087
# Loss after 37651 examples: 0.091
# Loss after 38784 examples: 0.085
# Loss after 39917 examples: 0.083
# Loss after 41089 examples: 0.093
# Loss after 42222 examples: 0.082
# Loss after 43355 examples: 0.092
# Loss after 44488 examples: 0.080
# Loss after 45621 examples: 0.063
# Loss after 46793 examples: 0.079
# Loss after 47926 examples: 0.084
# Loss after 49059 examples: 0.088
# Loss after 50192 examples: 0.084
# Loss after 51364 examples: 0.092
# Loss after 52497 examples: 0.080
# Loss after 53630 examples: 0.084
# Loss after 54763 examples: 0.080
# Loss after 55896 examples: 0.082
# Loss after 57068 examples: 0.085
# Loss after 58201 examples: 0.081
# Loss after 59334 examples: 0.073
# Loss after 60467 examples: 0.073
# Loss after 61639 examples: 0.087
# Loss after 62772 examples: 0.088
# Loss after 63905 examples: 0.072
# Loss after 65038 examples: 0.081
# Loss after 66171 examples: 0.102
# Loss after 67343 examples: 0.083
# Loss after 68476 examples: 0.075
# Loss after 69609 examples: 0.087
# Loss after 70742 examples: 0.085
# Loss after 71914 examples: 0.080
# Loss after 73047 examples: 0.078
# Loss after 74180 examples: 0.080
# Loss after 75313 examples: 0.070
# Loss after 76446 examples: 0.083
# Loss after 77618 examples: 0.074
# Loss after 78751 examples: 0.070
# Loss after 79884 examples: 0.083
# Loss after 81017 examples: 0.072
# Loss after 82189 examples: 0.078
# Loss after 83322 examples: 0.083
# Loss after 84455 examples: 0.080
# Loss after 85588 examples: 0.076
# Loss after 86721 examples: 0.075
# Loss after 87893 examples: 0.065
# Loss after 89026 examples: 0.059
# Loss after 90159 examples: 0.073
# Loss after 91292 examples: 0.080
# Loss after 512567 examples: 0.025
# Loss after 513739 examples: 0.031
# Loss after 514872 examples: 0.033
# Loss after 516005 examples: 0.035
# Loss after 517138 examples: 0.036
# Loss after 518271 examples: 0.053
# Loss after 519443 examples: 0.025
# Loss after 520576 examples: 0.034
# Loss after 521709 examples: 0.035
# Loss after 522842 examples: 0.028
# Loss after 524014 examples: 0.027
# Loss after 525147 examples: 0.026
# Loss after 526280 examples: 0.028
# Loss after 527413 examples: 0.034
# Loss after 528546 examples: 0.009
# Loss after 529718 examples: 0.037
# Loss after 530851 examples: 0.028
# Loss after 531984 examples: 0.032
# Loss after 533117 examples: 0.029
# Loss after 534289 examples: 0.037
# Loss after 535422 examples: 0.032
# Loss after 536555 examples: 0.029
# Loss after 537688 examples: 0.030
# Loss after 538821 examples: 0.026
# Loss after 539993 examples: 0.028
# Loss after 541126 examples: 0.029
# Loss after 542259 examples: 0.032
# Loss after 543392 examples: 0.030
# Loss after 544564 examples: 0.023
# Loss after 545697 examples: 0.027
# Loss after 546830 examples: 0.031
# Loss after 547963 examples: 0.033
# Loss after 549096 examples: 0.048
# Loss after 550268 examples: 0.029
# Loss after 551401 examples: 0.031
# Training completed.
#
# -----------------------------------------------------------------
# Begin model evaluation...
#
#
# Evaluate results on test data...
#
# Accuracy of the model on the 50 test waves: 86.0%
# Accuracy of the model on the 100 test waves: 86.0%
# Accuracy of the model on the 103 test waves: 86.40776699029126%
#
# Test Set Metrics:
#               precision    recall  f1-score   support
#
#        20deg       1.00      0.95      0.98        21
#        22deg       0.80      0.80      0.80        15
#        26deg       0.79      0.71      0.75        21
#        30deg       0.88      0.88      0.88        17
#        36deg       0.80      0.92      0.86        13
#        40deg       0.88      0.94      0.91        16
#
#     accuracy                           0.86       103
#    macro avg       0.86      0.87      0.86       103
# weighted avg       0.87      0.86      0.86       103
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.082 MB of 0.082 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▅▃▄▄▄▄▄▃▄▄▂▃▃▄▄▂▂▃▂▃▂▂▂▃▂▂▂▂▁▂▂▂▂▁▁▂▂▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.86408</td></tr><tr><td>epoch</td><td>1341</td></tr><tr><td>loss</td><td>0.03106</td></tr><tr><td>test_accuracy</td><td>0.86408</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">usual-sweep-2</strong>: <a href="https://wandb.ai/ae-ml_ucsb/plb-dataset/runs/6j9we3jw" target="_blank">https://wandb.ai/ae-ml_ucsb/plb-dataset/runs/6j9we3jw</a><br/>Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220527_121958-6j9we3jw/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: tr7xqdia with config:
# wandb: 	angles: ['20deg', '22deg', '26deg', '30deg', '36deg', '40deg']
# wandb: 	architecture: 1
# wandb: 	batch_size: 10
# wandb: 	classes: 6
# wandb: 	dt: 1e-07
# wandb: 	epochs: 1477
# wandb: 	feature_dim: 1024
# wandb: 	fft_units: 1000
# wandb: 	high_pass: 1000000
# wandb: 	learning_rate: 0.0098490938936763
# wandb: 	low_pass: 0
# wandb: 	num_bins: 26
# wandb: 	sig_len: 1024
# wandb: 	train_percent: 0.8
# wandb: 	train_seed: 41
# wandb: 	url: https://raw.githubusercontent.com/ntulshibagwale/plb_dataset_supervised_learning/main/Data/220426_PLB_data.json
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220527_122359-tr7xqdia</code>
# Syncing run <strong><a href="https://wandb.ai/ae-ml_ucsb/plb-dataset/runs/tr7xqdia" target="_blank">eager-sweep-3</a></strong> to <a href="https://wandb.ai/ae-ml_ucsb/plb-dataset" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ae-ml_ucsb/plb-dataset/sweeps/gjo2tho0" target="_blank">https://wandb.ai/ae-ml_ucsb/plb-dataset/sweeps/gjo2tho0</a>
# HYPER-Parameters:
# angles : ['20deg', '22deg', '26deg', '30deg', '36deg', '40deg']
# architecture : 1
# batch_size : 10
# classes : 6
# dt : 1e-07
# epochs : 1477
# feature_dim : 1024
# fft_units : 1000
# high_pass : 1000000
# learning_rate : 0.0098490938936763
# low_pass : 0
# num_bins : 26
# sig_len : 1024
# train_percent : 0.8
# train_seed : 41
# url : https://raw.githubusercontent.com/ntulshibagwale/plb_dataset_supervised_learning/main/Data/220426_PLB_data.json
#
# targets_one_hot is the one hot encoding for angle. ex: [1 0 1]
#
# Shape of waves is: torch.Size([514, 1024])
# Datatype of waves is: torch.float32
# waves requires grad: False
# Shape of targets is: torch.Size([514])
# Datatype of targets is: torch.int64
# targets requires grad: False
# Ex: 0
# Shape of targets_one_hot is: torch.Size([514, 6])
# Datatype of targets_one_hot is: torch.float32
# targets_one_hot requires grad: False
# Ex: tensor([1, 0, 0, 0, 0, 0])
#
# AcousticEmissionDataset loaded in!
#
# Shape of x batch is: torch.Size([10, 1024])
# Datatype of x batch is: torch.float32
#
# Shape of y batch is: torch.Size([10, 6])
# Datatype of y batch is: torch.float32
#
# NeuralNetwork_01(
#   (layers): Sequential(
#     (0): Linear(in_features=1024, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=6, bias=True)
#   )
# )
# -----------------------------------------------------------------
# Begin model training...
#   0%|          | 0/1477 [00:00<?, ?it/s]
# Loss after 00240 examples: 0.124
# Loss after 00481 examples: 0.102
# Loss after 00731 examples: 0.095
# Loss after 00972 examples: 0.064
# Loss after 01222 examples: 0.106
# Loss after 01463 examples: 0.083
# Loss after 01704 examples: 0.101
# Loss after 01954 examples: 0.098
# Loss after 02195 examples: 0.086
# Loss after 02445 examples: 0.104
# Loss after 02686 examples: 0.113
# Loss after 02927 examples: 0.058
# Loss after 03177 examples: 0.089
# Loss after 03418 examples: 0.113
# Loss after 03668 examples: 0.079
# Loss after 03909 examples: 0.076
# Loss after 04150 examples: 0.115
# Loss after 04400 examples: 0.108
# Loss after 04641 examples: 0.078
# Loss after 04891 examples: 0.083
# Loss after 05132 examples: 0.089
# Loss after 05373 examples: 0.105
# Loss after 05623 examples: 0.090
# Loss after 05864 examples: 0.088
# Loss after 06114 examples: 0.098
# Loss after 06355 examples: 0.090
# Loss after 06596 examples: 0.082
# Loss after 06846 examples: 0.097
# Loss after 07087 examples: 0.084
# Loss after 07337 examples: 0.103
# Loss after 07578 examples: 0.073
# Loss after 07819 examples: 0.103
# Loss after 08069 examples: 0.106
# Loss after 08310 examples: 0.097
# Loss after 372095 examples: 0.010
# Loss after 372345 examples: 0.013
# Loss after 372586 examples: 0.013
# Loss after 372827 examples: 0.011
# Loss after 373077 examples: 0.007
# Loss after 373318 examples: 0.008
# Loss after 373568 examples: 0.009
# Loss after 373809 examples: 0.009
# Loss after 374050 examples: 0.006
# Loss after 374300 examples: 0.014
# Loss after 374541 examples: 0.008
# Loss after 374791 examples: 0.011
# Loss after 375032 examples: 0.007
# Loss after 375273 examples: 0.003
# Loss after 375523 examples: 0.011
# Loss after 375764 examples: 0.015
# Loss after 376014 examples: 0.006
# Loss after 376255 examples: 0.011
# Loss after 376496 examples: 0.012
# Loss after 376746 examples: 0.007
# Loss after 376987 examples: 0.009
# Loss after 377237 examples: 0.011
# Loss after 377478 examples: 0.008
# Loss after 377719 examples: 0.006
# Loss after 377969 examples: 0.008
# Loss after 378210 examples: 0.010
# Loss after 378460 examples: 0.010
# Loss after 378701 examples: 0.011
# Loss after 378942 examples: 0.006
# Loss after 379192 examples: 0.007
# Loss after 379433 examples: 0.007
# Loss after 379683 examples: 0.008
# Loss after 379924 examples: 0.012
# Loss after 380174 examples: 0.008
# Loss after 380415 examples: 0.011
# Loss after 380656 examples: 0.008
# Loss after 380906 examples: 0.008
# Loss after 381147 examples: 0.003
# Loss after 381397 examples: 0.005
# Loss after 381638 examples: 0.004
# Loss after 381879 examples: 0.011
# Loss after 382129 examples: 0.014
# Loss after 382370 examples: 0.006
# Loss after 382620 examples: 0.008
# Loss after 382861 examples: 0.010
# Loss after 383102 examples: 0.013
# Loss after 383352 examples: 0.020
# Loss after 383593 examples: 0.006
# Loss after 383843 examples: 0.015
# Loss after 384084 examples: 0.004
# Loss after 384325 examples: 0.012
# Loss after 384575 examples: 0.005
# Loss after 384816 examples: 0.011
# Loss after 385066 examples: 0.008
# Loss after 385307 examples: 0.011
# Loss after 385548 examples: 0.010
# Loss after 385798 examples: 0.006
# Loss after 386039 examples: 0.010
# Loss after 386289 examples: 0.005
# Loss after 386530 examples: 0.007
# Loss after 386771 examples: 0.014
# Loss after 387021 examples: 0.010
# Loss after 387262 examples: 0.008
# Loss after 387512 examples: 0.007
# Loss after 387753 examples: 0.009
# Loss after 387994 examples: 0.005
# Loss after 388244 examples: 0.005
# Loss after 388485 examples: 0.008
# Loss after 388735 examples: 0.005
# Loss after 388976 examples: 0.012
# Loss after 389217 examples: 0.015
# Loss after 389467 examples: 0.008
# Loss after 389708 examples: 0.012
# Loss after 389958 examples: 0.008
# Loss after 390199 examples: 0.013
# Loss after 390449 examples: 0.010
# Loss after 390690 examples: 0.009
# Loss after 390931 examples: 0.010
# Loss after 391181 examples: 0.008
# Loss after 391422 examples: 0.018
# Loss after 391672 examples: 0.006
# Loss after 391913 examples: 0.004
# Loss after 392154 examples: 0.008
# Loss after 392404 examples: 0.011
# Loss after 392645 examples: 0.007
# Loss after 392895 examples: 0.016
# Loss after 393136 examples: 0.012
# Loss after 393377 examples: 0.011
# Loss after 393627 examples: 0.007
# Loss after 393868 examples: 0.004
# Loss after 394118 examples: 0.003
# Loss after 394359 examples: 0.007
# Loss after 394600 examples: 0.020
# Loss after 394850 examples: 0.006
# Loss after 395091 examples: 0.012
# Loss after 395341 examples: 0.005
# Loss after 395582 examples: 0.011
# Loss after 395823 examples: 0.011
# Loss after 396073 examples: 0.011
# Loss after 396314 examples: 0.005
# Loss after 396564 examples: 0.013
# Loss after 396805 examples: 0.008
# Loss after 397046 examples: 0.007
# Loss after 397296 examples: 0.010
# Loss after 397537 examples: 0.009
# Loss after 397787 examples: 0.010
# Loss after 398028 examples: 0.015
# Loss after 398269 examples: 0.004
# Loss after 398519 examples: 0.008
# Loss after 398760 examples: 0.010
# Loss after 399010 examples: 0.006
# Loss after 399251 examples: 0.012
# Loss after 399492 examples: 0.001
# Loss after 399742 examples: 0.012
# Loss after 399983 examples: 0.004
# Loss after 400233 examples: 0.007
# Loss after 400474 examples: 0.008
# Loss after 400724 examples: 0.007
# Loss after 400965 examples: 0.014
# Loss after 401206 examples: 0.009
# Loss after 401456 examples: 0.005
# Loss after 401697 examples: 0.007
# Loss after 401947 examples: 0.016
# Loss after 402188 examples: 0.011
# Loss after 402429 examples: 0.009
# Loss after 402679 examples: 0.011
# Loss after 402920 examples: 0.008
# Loss after 403170 examples: 0.018
# Loss after 403411 examples: 0.007
# Loss after 403652 examples: 0.008
# Loss after 403902 examples: 0.006
# Loss after 404143 examples: 0.014
# Loss after 404393 examples: 0.019
# Loss after 404634 examples: 0.008
# Loss after 404875 examples: 0.012
# Loss after 405125 examples: 0.008
# Loss after 405366 examples: 0.010
# Loss after 405616 examples: 0.013
# Loss after 405857 examples: 0.016
# Loss after 406098 examples: 0.006
# Loss after 406348 examples: 0.006
# Loss after 406589 examples: 0.011
# Loss after 406839 examples: 0.007
# Loss after 407080 examples: 0.021
# Loss after 407321 examples: 0.009
# Loss after 407571 examples: 0.013
# Loss after 407812 examples: 0.015
# Loss after 408062 examples: 0.005
# Loss after 408303 examples: 0.011
# Loss after 408544 examples: 0.008
# Loss after 408794 examples: 0.011
# Loss after 409035 examples: 0.007
# Loss after 409285 examples: 0.005
# Loss after 409526 examples: 0.010
# Loss after 409767 examples: 0.001
# Loss after 410017 examples: 0.011
# Loss after 410258 examples: 0.006
# Loss after 410508 examples: 0.007
# Loss after 410749 examples: 0.010
# Loss after 410999 examples: 0.005
# Loss after 411240 examples: 0.024
# Loss after 411481 examples: 0.008
# Loss after 411731 examples: 0.017
# Loss after 411972 examples: 0.008
# Loss after 412222 examples: 0.007
# Loss after 412463 examples: 0.005
# Loss after 412704 examples: 0.009
# Loss after 412954 examples: 0.008
# Loss after 413195 examples: 0.008
# Loss after 413445 examples: 0.012
# Loss after 413686 examples: 0.024
# Loss after 413927 examples: 0.008
# Loss after 414177 examples: 0.008
# Loss after 414418 examples: 0.020
# Loss after 414668 examples: 0.016
# Loss after 414909 examples: 0.005
# Loss after 415150 examples: 0.010
# Loss after 415400 examples: 0.014
# Loss after 415641 examples: 0.013
# Loss after 415891 examples: 0.010
# Loss after 416132 examples: 0.010
# Loss after 416373 examples: 0.009
# Loss after 416623 examples: 0.008
# Loss after 416864 examples: 0.008
# Loss after 417114 examples: 0.014
# Loss after 417355 examples: 0.008
# Loss after 417596 examples: 0.005
# Loss after 417846 examples: 0.009
# Loss after 418087 examples: 0.015
# Loss after 418337 examples: 0.011
# Loss after 418578 examples: 0.013
# Loss after 418819 examples: 0.013
# Loss after 419069 examples: 0.007
# Loss after 419310 examples: 0.020
# Loss after 419560 examples: 0.013
# Loss after 419801 examples: 0.014
# Loss after 420042 examples: 0.002
# Loss after 420292 examples: 0.018
# Loss after 420533 examples: 0.005
# Loss after 420783 examples: 0.012
# Training completed.
#
# -----------------------------------------------------------------
# Begin model evaluation...
#
#
# Evaluate results on test data...
#
# Accuracy of the model on the 10 test waves: 100.0%
# Accuracy of the model on the 20 test waves: 100.0%
# Accuracy of the model on the 30 test waves: 100.0%
# Accuracy of the model on the 40 test waves: 97.5%
# Accuracy of the model on the 50 test waves: 98.0%
# Accuracy of the model on the 60 test waves: 95.0%
# Accuracy of the model on the 70 test waves: 95.71428571428571%
# Accuracy of the model on the 80 test waves: 96.25%
# Accuracy of the model on the 90 test waves: 94.44444444444444%
# Accuracy of the model on the 100 test waves: 95.0%
# Accuracy of the model on the 103 test waves: 95.14563106796116%
#
# Test Set Metrics:
#               precision    recall  f1-score   support
#
#        20deg       1.00      1.00      1.00        20
#        22deg       0.93      1.00      0.97        14
#        26deg       1.00      0.90      0.95        21
#        30deg       0.88      0.88      0.88        17
#        36deg       0.93      1.00      0.97        14
#        40deg       0.94      0.94      0.94        17
#
#     accuracy                           0.95       103
#    macro avg       0.95      0.95      0.95       103
# weighted avg       0.95      0.95      0.95       103
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.082 MB of 0.082 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>██▆▄▆▅▄▄▃▄▄▄▃▃▂▃▃▂▂▁▂▂▂▁▁▂▂▂▂▁▁▁▁▂▂▂▁▁▃▂</td></tr><tr><td>test_accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.95146</td></tr><tr><td>epoch</td><td>1023</td></tr><tr><td>loss</td><td>0.01173</td></tr><tr><td>test_accuracy</td><td>0.95146</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dark-sweep-10</strong>: <a href="https://wandb.ai/ae-ml_ucsb/plb-dataset/runs/iz39lnbv" target="_blank">https://wandb.ai/ae-ml_ucsb/plb-dataset/runs/iz39lnbv</a><br/>Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220527_131657-iz39lnbv/logs</code>

# %%
# Inputs
config = dict(
    epochs=1000,
    classes=6,
    batch_size=128,
    learning_rate=0.005,
    url = 'https://raw.githubusercontent.com/ntulshibagwale/plb_dataset_supervised_learning/main/Data/220426_PLB_data.json',
    architecture= 1,
    feature_dim = 1024, # raw waveform
    sig_len = 1024,
    dt = 10**-7,
    low_pass = 0,
    high_pass = 100*10**4,
    fft_units = 1000,
    num_bins=26,
    train_seed = 41, # THIS ENSURES SAME SPLIT FOR TEST DATA EVERY RUN
    train_percent = 0.8,
    angles = ['20deg', '22deg', '26deg', '30deg', '36deg', '40deg']
    )

# Build, train and analyze the model with the pipeline
model = model_pipeline(config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-35a6d5ef03a0> in <module>()
#      20
#      21 # Build, train and analyze the model with the pipeline
# ---> 22 model = model_pipeline(config)
#
# TypeError: model_pipeline() takes 0 positional arguments but 1 was given
